# %% [markdown]
# # <center><font color = '#DF9166' size = 20 center> **Model Evaluation**</font></center>

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Table of content**<font/><a class = 'anchor' id = 'introduction'/>

# %% [markdown]
# 1. [**Import Libraries**](#import)
# 2. [**Data Loading**](#data_loading)
# 3. [**Model Evaluation**](#model_evaluation)

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Import Libraries**<font/><a class = 'anchor' id = 'import'/>

# %%
import os
import sys
import warnings

warnings.filterwarnings("ignore")

# %%
sys.path.append(os.path.abspath(os.path.pardir))
from scripts.train_models import TimeSeriesModel

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Data Loading**<font/><a class = 'anchor' id = 'data_loading'/>

# %%
DATA_PATH = "../data/raw/BrentOilPrices.csv"

model = TimeSeriesModel(DATA_PATH)

# %%
model.df.head()
# Out:
#             Price
# Date
# 1987-05-20  18.63
# 1987-05-21  18.45
# 1987-05-22  18.55
# 1987-05-25  18.60
# 1987-05-26  18.63

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Model Evaluation**<font/><a class = 'anchor' id = 'model_evaluation'/>

# %%
model.evaluate_model("arima")
# Out:
# /home/naod/miniconda3/envs/w8-env/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# {'RMSE': np.float64(24.833934902765847), 'MAE': 18.484341205477925}

# %%
model.evaluate_model("garch")
# Out:
# {'RMSE': np.float64(66.10064476171749), 'MAE': 62.79716065059001}

# %%
model.evaluate_model("random_forest")
# Out:
# {'RMSE': 25.024446550931607,
#  'MAE': 18.641006100942878,
#  'R2 Score': -0.4708279456617135}

# %%
model.evaluate_model("xgboost")
# Out:
# {'RMSE': 0.7063634468736104,
#  'MAE': 0.4364734982960387,
#  'R2 Score': 0.9988329147011931}

# %%
model.evaluate_model("lightgbm")
# Out:
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=0.8, subsample=1.0 will be ignored. Current value: bagging_fraction=0.8
# [LightGBM] [Warning] bagging_freq is set=5, subsample_freq=0 will be ignored. Current value: bagging_freq=5
# {'RMSE': 0.645610396496162,
#  'MAE': 0.3755203842090026,
#  'R2 Score': 0.9990250391091152}

# %%
model.evaluate_model("ensemble")
# Out:
# {'RMSE': 0.8175128750549348,
#  'MAE': 0.3395451108869834,
#  'R2 Score': 0.9984367250583915}
