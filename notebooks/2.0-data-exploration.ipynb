# %% [markdown]
# # <center><font color = '#DF9166' size = 20 center> **Data Exploration**</font></center>

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Table of content**<font/><a class = 'anchor' id = 'introduction'/>

# %% [markdown]
# 1. [**Import Libraries**](#import)
# 2. [**Data Loading**](#data_loading)
# 3. [**Exploratory Data Analysis**](#eda)

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Import Libraries**<font/><a class = 'anchor' id = 'import'/>

# %%
import os
import sys
import pandas as pd

# %%
import warnings

warnings.filterwarnings("ignore")

# %%
pd.set_option("display.max_colwidth", None)
pd.set_option("display.max_columns", None)

# %%
sys.path.append(os.path.abspath(os.path.pardir))
from scripts.explore_data import TimeSeriesEDA

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Data Loading**<font/><a class = 'anchor' id = 'data_loading'/>

# %%
DATA_PATH = "../data/raw/BrentOilPrices.csv"

# %%
df = pd.read_csv(DATA_PATH)
df.head(2)
# Out:
#         Date  Price
# 0  20-May-87  18.63
# 1  21-May-87  18.45

# %%
eda = TimeSeriesEDA(df)
# Out:
# ✔ Date column converted to datetime and set as index.

# %% [markdown]
# ## <font color = '#DF9166' size=6>**Exploratory Data Analysis**<font/><a class = 'anchor' id = 'eda'/>

# %%
# Print dataset summary
eda.data_summary()
# Out:
# Dataset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9011 entries, 1987-05-20 to 2022-11-14
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   9011 non-null   float64
# dtypes: float64(1)
# memory usage: 140.8 KB
# None
#
# Shape of dataset: (9011, 1)
#
# Basic Statistics:
#              Price
# count  9011.000000
# mean     48.420782
# std      32.860110
# min       9.100000
# 25%      19.050000
# 50%      38.570000
# 75%      70.090000
# max     143.950000

# %%
# Plot 30-day moving average
eda.plot_moving_average(30)

# %% [markdown]
# The graph displays the 30-day moving average (red) of oil prices alongside actual prices (blue) over several decades. It shows significant price fluctuations, with notable peaks around 2008, 2012, and 2022, and sharp declines during financial crises and economic downturns.

# %%
# Plot ACF and PACF
eda.plot_acf_pacf()

# %% [markdown]
# The ACF plot shows strong persistence, indicating non-stationarity, while the PACF suggests only the first few lags are significant, implying a potential AR(1) process.

# %%
# Perform time series decomposition
eda.decompose_time_series()

# %% [markdown]
# The decomposition plot shows an increasing trend in oil prices, a strong seasonal pattern, and residuals with higher volatility around 2008, indicating a significant shock during that period.

# %%
eda.plot_monthly_yearly_trends()  # Plot monthly and yearly trends

# %% [markdown]
# The first graph shows a seasonal price pattern, peaking mid-year, while the second graph indicates a long-term upward trend with volatility.
